# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9543e731-aa2b-452a-808d-f1f8f89edb79" name="files[]" multiple disabled />
#      <output id="result-9543e731-aa2b-452a-808d-f1f8f89edb79">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Churn_Modelling.csv to Churn_Modelling.csv

# %%
# Importing the dataset
dataset = pd.read_csv('Churn_Modelling.csv')

# %%
dataset
# Out:
#       RowNumber  CustomerId    Surname  ...  IsActiveMember EstimatedSalary Exited
# 0             1    15634602   Hargrave  ...               1       101348.88      1
# 1             2    15647311       Hill  ...               1       112542.58      0
# 2             3    15619304       Onio  ...               0       113931.57      1
# 3             4    15701354       Boni  ...               0        93826.63      0
# 4             5    15737888   Mitchell  ...               1        79084.10      0
# ...         ...         ...        ...  ...             ...             ...    ...
# 9995       9996    15606229   Obijiaku  ...               0        96270.64      0
# 9996       9997    15569892  Johnstone  ...               1       101699.77      0
# 9997       9998    15584532        Liu  ...               1        42085.58      1
# 9998       9999    15682355  Sabbatini  ...               0        92888.52      1
# 9999      10000    15628319     Walker  ...               0        38190.78      0
#
# [10000 rows x 14 columns]

# %%
X = dataset.iloc[:, 3:13].values
y = dataset.iloc[:, 13].values

# %%
# Encoding categorical data
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_X_1 = LabelEncoder()
X[:, 1] = labelencoder_X_1.fit_transform(X[:, 1])
labelencoder_X_2 = LabelEncoder()
X[:, 2] = labelencoder_X_2.fit_transform(X[:, 2])
onehotencoder = OneHotEncoder()
X_col = X[:, 1]
X_col = onehotencoder.fit_transform(X_col.reshape(-1,1)).toarray()
X = np.delete(X, 1, 1)
X = np.concatenate((X_col, X), axis = 1)
X = X[:, 1:]
X = X.astype('float64')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
#Initialising the ANN
classifier = Sequential()

# %%
#Adding the input layer and the first hidden layer
classifier.add(Dense(output_dim = 6, init = 'uniform', activation = 'relu', input_dim = 11))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", input_dim=11, units=6, kernel_initializer="uniform")`
#   """Entry point for launching an IPython kernel.

# %%
#Adding the second hidden layer
classifier.add(Dense(output_dim = 6, init = 'uniform', activation = 'relu'))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=6, kernel_initializer="uniform")`
#   """Entry point for launching an IPython kernel.

# %%
# Adding the output layer
classifier.add(Dense(output_dim = 1, init = 'uniform', activation = 'sigmoid'))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=1, kernel_initializer="uniform")`
#   """Entry point for launching an IPython kernel.

# %%
# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# Fitting the ANN to the Training set
classifier.fit(X_train, y_train, batch_size = 10, nb_epoch = 100)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   """Entry point for launching an IPython kernel.
# Epoch 1/100
# 8000/8000 [==============================] - 1s 142us/step - loss: 0.4830 - accuracy: 0.7955
# Epoch 2/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.4292 - accuracy: 0.7960
# Epoch 3/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.4244 - accuracy: 0.7960
# Epoch 4/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.4207 - accuracy: 0.8095
# Epoch 5/100
# 8000/8000 [==============================] - 1s 106us/step - loss: 0.4181 - accuracy: 0.8226
# Epoch 6/100
# 8000/8000 [==============================] - 1s 110us/step - loss: 0.4158 - accuracy: 0.8275
# Epoch 7/100
# 8000/8000 [==============================] - 1s 109us/step - loss: 0.4137 - accuracy: 0.8305
# Epoch 8/100
# 8000/8000 [==============================] - 1s 111us/step - loss: 0.4125 - accuracy: 0.8313
# Epoch 9/100
# 8000/8000 [==============================] - 1s 110us/step - loss: 0.4116 - accuracy: 0.8332
# Epoch 10/100
# 8000/8000 [==============================] - 1s 111us/step - loss: 0.4103 - accuracy: 0.8328
# Epoch 11/100
# 8000/8000 [==============================] - 1s 110us/step - loss: 0.4084 - accuracy: 0.8347
# Epoch 12/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.4084 - accuracy: 0.8345
# Epoch 13/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.4075 - accuracy: 0.8346
# Epoch 14/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.4072 - accuracy: 0.8349
# Epoch 15/100
# 8000/8000 [==============================] - 1s 100us/step - loss: 0.4066 - accuracy: 0.8335
# Epoch 16/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.4059 - accuracy: 0.8364
# Epoch 17/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.4058 - accuracy: 0.8359
# Epoch 18/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.4049 - accuracy: 0.8355
# Epoch 19/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.4052 - accuracy: 0.8341
# Epoch 20/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.4048 - accuracy: 0.8341
# Epoch 21/100
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.4042 - accuracy: 0.8353
# Epoch 22/100
# 8000/8000 [==============================] - 1s 106us/step - loss: 0.4045 - accuracy: 0.8354
# Epoch 23/100
# 8000/8000 [==============================] - 1s 105us/step - loss: 0.4041 - accuracy: 0.8365
# Epoch 24/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.4040 - accuracy: 0.8341
# Epoch 25/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.4040 - accuracy: 0.8345
# Epoch 26/100
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.4037 - accuracy: 0.8349
# Epoch 27/100
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.4037 - accuracy: 0.8346
# Epoch 28/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.4033 - accuracy: 0.8344
# Epoch 29/100
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.4034 - accuracy: 0.8347
# Epoch 30/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.4030 - accuracy: 0.8344
# Epoch 31/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.4029 - accuracy: 0.8355
# Epoch 32/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.4023 - accuracy: 0.8344
# Epoch 33/100
# 8000/8000 [==============================] - 1s 107us/step - loss: 0.4019 - accuracy: 0.8347
# Epoch 34/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.4009 - accuracy: 0.8353
# Epoch 35/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.4010 - accuracy: 0.8356
# Epoch 36/100
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.4007 - accuracy: 0.8354
# Epoch 37/100
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.3997 - accuracy: 0.8342
# Epoch 38/100
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.3992 - accuracy: 0.8355
# Epoch 39/100
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.3985 - accuracy: 0.8350
# Epoch 40/100
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.3991 - accuracy: 0.8345
# Epoch 41/100
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.3987 - accuracy: 0.8366
# Epoch 42/100
# 8000/8000 [==============================] - 1s 106us/step - loss: 0.3981 - accuracy: 0.8354
# Epoch 43/100
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.3976 - accuracy: 0.8345
# Epoch 44/100
# 8000/8000 [==============================] - 1s 105us/step - loss: 0.3979 - accuracy: 0.8359
# Epoch 45/100
# 8000/8000 [==============================] - 1s 108us/step - loss: 0.3968 - accuracy: 0.8361
# Epoch 46/100
# 8000/8000 [==============================] - 1s 111us/step - loss: 0.3977 - accuracy: 0.8351
# Epoch 47/100
# 8000/8000 [==============================] - 1s 107us/step - loss: 0.3964 - accuracy: 0.8361
# Epoch 48/100
# 8000/8000 [==============================] - 1s 105us/step - loss: 0.3969 - accuracy: 0.8345
# Epoch 49/100
# 8000/8000 [==============================] - 1s 106us/step - loss: 0.3970 - accuracy: 0.8347
# Epoch 50/100
# 8000/8000 [==============================] - 1s 107us/step - loss: 0.3965 - accuracy: 0.8355
# Epoch 51/100
# 8000/8000 [==============================] - 1s 106us/step - loss: 0.3961 - accuracy: 0.8363
# Epoch 52/100
# 8000/8000 [==============================] - 1s 109us/step - loss: 0.3963 - accuracy: 0.8376
# Epoch 53/100
# 8000/8000 [==============================] - 1s 107us/step - loss: 0.3961 - accuracy: 0.8355
# Epoch 54/100
# 8000/8000 [==============================] - 1s 108us/step - loss: 0.3957 - accuracy: 0.8359
# Epoch 55/100
# 8000/8000 [==============================] - 1s 107us/step - loss: 0.3961 - accuracy: 0.8365
# Epoch 56/100
# 8000/8000 [==============================] - 1s 111us/step - loss: 0.3953 - accuracy: 0.8354
# Epoch 57/100
# 8000/8000 [==============================] - 1s 106us/step - loss: 0.3956 - accuracy: 0.8371
# Epoch 58/100
# 8000/8000 [==============================] - 1s 108us/step - loss: 0.3958 - accuracy: 0.8374
# Epoch 59/100
# 8000/8000 [==============================] - 1s 106us/step - loss: 0.3953 - accuracy: 0.8361
# Epoch 60/100
# 8000/8000 [==============================] - 1s 106us/step - loss: 0.3956 - accuracy: 0.8345
# Epoch 61/100
# 8000/8000 [==============================] - 1s 106us/step - loss: 0.3951 - accuracy: 0.8359
# Epoch 62/100
# 8000/8000 [==============================] - 1s 105us/step - loss: 0.3954 - accuracy: 0.8364
# Epoch 63/100
# 8000/8000 [==============================] - 1s 107us/step - loss: 0.3948 - accuracy: 0.8357
# Epoch 64/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.3950 - accuracy: 0.8360
# Epoch 65/100
# 8000/8000 [==============================] - 1s 109us/step - loss: 0.3945 - accuracy: 0.8356
# Epoch 66/100
# 8000/8000 [==============================] - 1s 105us/step - loss: 0.3953 - accuracy: 0.8371
# Epoch 67/100
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.3943 - accuracy: 0.8361
# Epoch 68/100
# 8000/8000 [==============================] - 1s 106us/step - loss: 0.3950 - accuracy: 0.8365
# Epoch 69/100
# 8000/8000 [==============================] - 1s 106us/step - loss: 0.3952 - accuracy: 0.8374
# Epoch 70/100
# 8000/8000 [==============================] - 1s 110us/step - loss: 0.3950 - accuracy: 0.8367
# Epoch 71/100
# 8000/8000 [==============================] - 1s 105us/step - loss: 0.3946 - accuracy: 0.8354
# Epoch 72/100
# 8000/8000 [==============================] - 1s 105us/step - loss: 0.3940 - accuracy: 0.8376
# Epoch 73/100
# 8000/8000 [==============================] - 1s 106us/step - loss: 0.3950 - accuracy: 0.8359
# Epoch 74/100
# 8000/8000 [==============================] - 1s 106us/step - loss: 0.3939 - accuracy: 0.8364
# Epoch 75/100
# 8000/8000 [==============================] - 1s 109us/step - loss: 0.3946 - accuracy: 0.8355
# Epoch 76/100
# 8000/8000 [==============================] - 1s 107us/step - loss: 0.3944 - accuracy: 0.8385
# Epoch 77/100
# 8000/8000 [==============================] - 1s 109us/step - loss: 0.3944 - accuracy: 0.8381
# Epoch 78/100
# 8000/8000 [==============================] - 1s 107us/step - loss: 0.3939 - accuracy: 0.8370
# Epoch 79/100
# 8000/8000 [==============================] - 1s 107us/step - loss: 0.3945 - accuracy: 0.8376
# Epoch 80/100
# 8000/8000 [==============================] - 1s 107us/step - loss: 0.3941 - accuracy: 0.8375
# Epoch 81/100
# 8000/8000 [==============================] - 1s 110us/step - loss: 0.3940 - accuracy: 0.8359
# Epoch 82/100
# 8000/8000 [==============================] - 1s 106us/step - loss: 0.3940 - accuracy: 0.8378
# Epoch 83/100
# 8000/8000 [==============================] - 1s 105us/step - loss: 0.3945 - accuracy: 0.8359
# Epoch 84/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.3943 - accuracy: 0.8372
# Epoch 85/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.3940 - accuracy: 0.8371
# Epoch 86/100
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.3940 - accuracy: 0.8385
# Epoch 87/100
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.3934 - accuracy: 0.8384
# Epoch 88/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.3937 - accuracy: 0.8376
# Epoch 89/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.3934 - accuracy: 0.8372
# Epoch 90/100
# 8000/8000 [==============================] - 1s 105us/step - loss: 0.3939 - accuracy: 0.8372
# Epoch 91/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.3936 - accuracy: 0.8374
# Epoch 92/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.3935 - accuracy: 0.8374
# Epoch 93/100
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.3937 - accuracy: 0.8369
# Epoch 94/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.3936 - accuracy: 0.8372
# Epoch 95/100
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.3934 - accuracy: 0.8378
# Epoch 96/100
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.3934 - accuracy: 0.8376
# Epoch 97/100
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.3932 - accuracy: 0.8379
# Epoch 98/100
# 8000/8000 [==============================] - 1s 103us/step - loss: 0.3935 - accuracy: 0.8381
# Epoch 99/100
# 8000/8000 [==============================] - 1s 105us/step - loss: 0.3929 - accuracy: 0.8366
# Epoch 100/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.3936 - accuracy: 0.8374

# %%
# Part 3 - Making the predictions and evaluating the model

# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
cm
# Out:
# array([[1547,   48],
#        [ 263,  142]])

# %%
y_pred
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])
